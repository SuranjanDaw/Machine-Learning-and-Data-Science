# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.preprocessing import MinMaxScaler as MMS
from sklearn.model_selection import train_test_split as tts
from sklearn.linear_model import LogisticRegression as LogReg
from sklearn.tree import DecisionTreeClassifier as DTC
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

# %%
data = pd.read_csv('data_cleaned_churn.csv')

# %%
data
# Out:
#        Unnamed: 0  vintage  age  dependents    city  customer_nw_category  \
# 0               0     3135   66         0.0   187.0                     2
# 1               1      310   35         0.0  1020.0                     2
# 2               2     2356   31         0.0   146.0                     2
# 3               3      478   90         0.0  1020.0                     2
# 4               4     2531   42         2.0  1494.0                     3
# ...           ...      ...  ...         ...     ...                   ...
# 27882       28377     1845   10         0.0  1020.0                     2
# 27883       28378     4919   34         0.0  1046.0                     2
# 27884       28379      297   47         0.0  1096.0                     2
# 27885       28380     2585   50         3.0  1219.0                     3
# 27886       28381     2349   18         0.0  1232.0                     2
#
#        days_since_last_transaction  current_balance  \
# 0                            224.0          1458.71
# 1                             60.0          5390.37
# 2                             31.0          3913.16
# 3                            147.0          2291.91
# 4                             58.0           927.72
# ...                            ...              ...
# 27882                         70.0          1076.43
# 27883                         14.0          3844.10
# 27884                          0.0         65511.97
# 27885                         31.0          1625.55
# 27886                         59.0          2107.05
#
#        previous_month_end_balance  average_monthly_balance_prevQ  ...  \
# 0                         1458.71                        1458.71  ...
# 1                         8704.66                        7799.26  ...
# 2                         5815.29                        4910.17  ...
# 3                         2291.91                        2084.54  ...
# 4                         1401.72                        1643.31  ...
# ...                           ...                            ...  ...
# 27882                     1076.43                        2282.19  ...
# 27883                     4069.21                        3668.83  ...
# 27884                    61017.55                       53444.81  ...
# 27885                     1625.55                        1683.20  ...
# 27886                     2821.34                        3213.44  ...
#
#        current_month_credit  previous_month_credit  current_month_debit  \
# 0                      0.20                   0.20                 0.20
# 1                      0.56                   0.56              5486.27
# 2                      0.61                   0.61              6046.73
# 3                      0.47                   0.47                 0.47
# 4                      0.33                 714.61               588.62
# ...                     ...                    ...                  ...
# 27882                  0.30                   0.30                 0.30
# 27883                  1.71                   2.29               901.00
# 27884               4666.84                3883.06               168.23
# 27885                  0.20                   0.20                 0.20
# 27886                  0.11                   7.44               714.40
#
#        previous_month_debit  current_month_balance  previous_month_balance  \
# 0                      0.20                1458.71                 1458.71
# 1                    100.56                6496.78                 8787.61
# 2                    259.23                5006.28                 5070.14
# 3                   2143.33                2291.91                 1669.79
# 4                   1538.06                1157.15                 1677.16
# ...                     ...                    ...                     ...
# 27882                  0.30                1076.43                 1076.43
# 27883               1014.07                3738.54                 3690.32
# 27884                 71.80               61078.50                57564.24
# 27885                  0.20                1625.55                 1625.55
# 27886               1094.09                2402.62                 3260.58
#
#        churn  gender_cat  occupation_cat  branch_code_cat
# 0          0           1               3              676
# 1          0           1               3             2680
# 2          0           1               2               40
# 3          1           1               3              530
# 4          1           1               3              364
# ...      ...         ...             ...              ...
# 27882      0           0               4             1006
# 27883      0           0               3              205
# 27884      1           1               2              536
# 27885      0           1               3              252
# 27886      1           1               4              449
#
# [27887 rows x 21 columns]

# %%
data.drop(labels='Unnamed: 0', axis=1,inplace=True)

# %%
data.boxplot()

# %%
Y = data['churn']
Y
# Out:
# 0        0
# 1        0
# 2        0
# 3        1
# 4        1
#         ..
# 27882    0
# 27883    0
# 27884    1
# 27885    0
# 27886    1
# Name: churn, Length: 27887, dtype: int64

# %%
X = data.drop(labels='churn', axis=1, inplace=False)
X
# Out:
#        vintage  age  dependents    city  customer_nw_category  \
# 0         3135   66         0.0   187.0                     2
# 1          310   35         0.0  1020.0                     2
# 2         2356   31         0.0   146.0                     2
# 3          478   90         0.0  1020.0                     2
# 4         2531   42         2.0  1494.0                     3
# ...        ...  ...         ...     ...                   ...
# 27882     1845   10         0.0  1020.0                     2
# 27883     4919   34         0.0  1046.0                     2
# 27884      297   47         0.0  1096.0                     2
# 27885     2585   50         3.0  1219.0                     3
# 27886     2349   18         0.0  1232.0                     2
#
#        days_since_last_transaction  current_balance  \
# 0                            224.0          1458.71
# 1                             60.0          5390.37
# 2                             31.0          3913.16
# 3                            147.0          2291.91
# 4                             58.0           927.72
# ...                            ...              ...
# 27882                         70.0          1076.43
# 27883                         14.0          3844.10
# 27884                          0.0         65511.97
# 27885                         31.0          1625.55
# 27886                         59.0          2107.05
#
#        previous_month_end_balance  average_monthly_balance_prevQ  \
# 0                         1458.71                        1458.71
# 1                         8704.66                        7799.26
# 2                         5815.29                        4910.17
# 3                         2291.91                        2084.54
# 4                         1401.72                        1643.31
# ...                           ...                            ...
# 27882                     1076.43                        2282.19
# 27883                     4069.21                        3668.83
# 27884                    61017.55                       53444.81
# 27885                     1625.55                        1683.20
# 27886                     2821.34                        3213.44
#
#        average_monthly_balance_prevQ2  current_month_credit  \
# 0                             1449.07                  0.20
# 1                            12419.41                  0.56
# 2                             2815.94                  0.61
# 3                             1006.54                  0.47
# 4                             1871.12                  0.33
# ...                               ...                   ...
# 27882                         2787.70                  0.30
# 27883                         3865.55                  1.71
# 27884                        21925.81               4666.84
# 27885                         1857.42                  0.20
# 27886                         4447.45                  0.11
#
#        previous_month_credit  current_month_debit  previous_month_debit  \
# 0                       0.20                 0.20                  0.20
# 1                       0.56              5486.27                100.56
# 2                       0.61              6046.73                259.23
# 3                       0.47                 0.47               2143.33
# 4                     714.61               588.62               1538.06
# ...                      ...                  ...                   ...
# 27882                   0.30                 0.30                  0.30
# 27883                   2.29               901.00               1014.07
# 27884                3883.06               168.23                 71.80
# 27885                   0.20                 0.20                  0.20
# 27886                   7.44               714.40               1094.09
#
#        current_month_balance  previous_month_balance  gender_cat  \
# 0                    1458.71                 1458.71           1
# 1                    6496.78                 8787.61           1
# 2                    5006.28                 5070.14           1
# 3                    2291.91                 1669.79           1
# 4                    1157.15                 1677.16           1
# ...                      ...                     ...         ...
# 27882                1076.43                 1076.43           0
# 27883                3738.54                 3690.32           0
# 27884               61078.50                57564.24           1
# 27885                1625.55                 1625.55           1
# 27886                2402.62                 3260.58           1
#
#        occupation_cat  branch_code_cat
# 0                   3              676
# 1                   3             2680
# 2                   2               40
# 3                   3              530
# 4                   3              364
# ...               ...              ...
# 27882               4             1006
# 27883               3              205
# 27884               2              536
# 27885               3              252
# 27886               4              449
#
# [27887 rows x 19 columns]

# %%
minMax = MMS()
X_scaled = minMax.fit_transform(X)

# %%
X_scaled
# Out:
# array([[0.23232959, 0.73033708, 0.        , ..., 1.        , 0.75      ,
#         0.21264549],
#        [0.01022093, 0.38202247, 0.        , ..., 1.        , 0.75      ,
#         0.8430324 ],
#        [0.17108263, 0.33707865, 0.        , ..., 1.        , 0.5       ,
#         0.01258257],
#        ...,
#        [0.00919884, 0.51685393, 0.        , ..., 1.        , 0.5       ,
#         0.16860648],
#        [0.18908719, 0.5505618 , 0.33333333, ..., 1.        , 0.75      ,
#         0.07927021],
#        [0.17053227, 0.19101124, 0.        , ..., 1.        , 1.        ,
#         0.14123938]])

# %%
X_train = pd.DataFrame(X_scaled, columns=X.columns)

# %%
X_train
# Out:
#         vintage       age  dependents      city  customer_nw_category  \
# 0      0.232330  0.730337    0.000000  0.113402                   0.5
# 1      0.010221  0.382022    0.000000  0.618557                   0.5
# 2      0.171083  0.337079    0.000000  0.088539                   0.5
# 3      0.023430  1.000000    0.000000  0.618557                   0.5
# 4      0.184842  0.460674    0.222222  0.906004                   1.0
# ...         ...       ...         ...       ...                   ...
# 27882  0.130907  0.101124    0.000000  0.618557                   0.5
# 27883  0.372592  0.370787    0.000000  0.634324                   0.5
# 27884  0.009199  0.516854    0.000000  0.664645                   0.5
# 27885  0.189087  0.550562    0.333333  0.739236                   1.0
# 27886  0.170532  0.191011    0.000000  0.747119                   0.5
#
#        days_since_last_transaction  current_balance  \
# 0                         0.613699         0.014622
# 1                         0.164384         0.054034
# 2                         0.084932         0.039226
# 3                         0.402740         0.022974
# 4                         0.158904         0.009300
# ...                            ...              ...
# 27882                     0.191781         0.010790
# 27883                     0.038356         0.038534
# 27884                     0.000000         0.656704
# 27885                     0.084932         0.016295
# 27886                     0.161644         0.021121
#
#        previous_month_end_balance  average_monthly_balance_prevQ  \
# 0                        0.014622                       0.000305
# 1                        0.087257                       0.064788
# 2                        0.058293                       0.035406
# 3                        0.022974                       0.006670
# 4                        0.014051                       0.002183
# ...                           ...                            ...
# 27882                    0.010790                       0.008680
# 27883                    0.040790                       0.022782
# 27884                    0.611651                       0.528995
# 27885                    0.016294                       0.002588
# 27886                    0.028281                       0.018151
#
#        average_monthly_balance_prevQ2  current_month_credit  \
# 0                            0.014541              0.000002
# 1                            0.124629              0.000006
# 2                            0.028258              0.000006
# 3                            0.010100              0.000005
# 4                            0.018776              0.000003
# ...                               ...                   ...
# 27882                        0.027974              0.000003
# 27883                        0.038791              0.000017
# 27884                        0.220027              0.047344
# 27885                        0.018639              0.000002
# 27886                        0.044630              0.000001
#
#        previous_month_credit  current_month_debit  previous_month_debit  \
# 0                   0.000002             0.000002              0.000002
# 1                   0.000006             0.055657              0.001016
# 2                   0.000006             0.061343              0.002620
# 3                   0.000005             0.000005              0.021660
# 4                   0.007222             0.005971              0.015543
# ...                      ...                  ...                   ...
# 27882               0.000003             0.000003              0.000003
# 27883               0.000023             0.009140              0.010248
# 27884               0.039246             0.001707              0.000725
# 27885               0.000002             0.000002              0.000002
# 27886               0.000075             0.007247              0.011056
#
#        current_month_balance  previous_month_balance  gender_cat  \
# 0                   0.014622                0.014622         1.0
# 1                   0.065124                0.088088         1.0
# 2                   0.050183                0.050823         1.0
# 3                   0.022974                0.016738         1.0
# 4                   0.011599                0.016812         1.0
# ...                      ...                     ...         ...
# 27882               0.010790                0.010790         0.0
# 27883               0.037475                0.036992         0.0
# 27884               0.612262                0.577034         1.0
# 27885               0.016294                0.016294         1.0
# 27886               0.024084                0.032684         1.0
#
#        occupation_cat  branch_code_cat
# 0                0.75         0.212645
# 1                0.75         0.843032
# 2                0.50         0.012583
# 3                0.75         0.166719
# 4                0.75         0.114501
# ...               ...              ...
# 27882            1.00         0.316452
# 27883            0.75         0.064486
# 27884            0.50         0.168606
# 27885            0.75         0.079270
# 27886            1.00         0.141239
#
# [27887 rows x 19 columns]

# %%
train_x, test_x, train_y, test_y = tts(X_train, Y, random_state=52, stratify=Y)

# %% [markdown]
# # Logistic Regression

# %%
log = LogReg()
log.fit(train_x, train_y)
my_pred = log.predict(train_x)
train_score = f1_score(my_pred, train_y)
print('Logistic Reg Train: ',train_score)
my_pred_test = log.predict(test_x)
test_score = f1_score(my_pred_test, test_y)
print('Logistic Reg Test: ',test_score)
# Out:
# Logistic Reg Train:  0.17277726856095324
# Logistic Reg Test:  0.17319587628865976
# /home/suranjan/miniconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:938: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# # Decision Tree

# %%
decision = DTC()
decision.fit(train_x, train_y)
my_pred = decision.predict(train_x)
train_score = f1_score(my_pred, train_y)
print('Decision Tree Classifier Train: ',train_score)
my_pred_test = decision.predict(test_x)
test_score = f1_score(my_pred_test, test_y)
print('Decision Tree Classifier Test: ',test_score)
# Out:
# Decision Tree Classifier Train:  1.0
# Decision Tree Classifier Test:  0.45734050730207537

# %% [markdown]
# # KNN model

# %%
knn = KNN(n_neighbors=10)
knn.fit(train_x, train_y)
my_pred = knn.predict(train_x)
train_score = f1_score(my_pred, train_y)
print('KNN Classifier Train: ',train_score)
my_pred_test = knn.predict(test_x)
test_score = f1_score(my_pred_test, test_y)
print('KNN Classifier Test: ',test_score)
# Out:
# KNN Classifier Train:  0.0718232044198895
# KNN Classifier Test:  0.03942380591357088
