# %% [markdown]
# # Housing Price Prediction Model

# %% [markdown]
# ## Data Exploration

# %%
import pandas as pd
import numpy as np

# %%
# Loading data
data = pd.read_csv("read_csv/chennai_house_price_prediction.csv")

# %%
data
# Out:
#       PRT_ID        AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  \
# 0     P03210  Karapakkam      1004            131        1.0         1.0
# 1     P09411  Anna Nagar      1986             26        2.0         1.0
# 2     P01812       Adyar       909             70        1.0         1.0
# 3     P05346   Velachery      1855             14        3.0         2.0
# 4     P06210  Karapakkam      1226             84        1.0         1.0
# ...      ...         ...       ...            ...        ...         ...
# 7104  P03834  Karapakkam       598             51        1.0         1.0
# 7105  P10000   Velachery      1897             52        3.0         2.0
# 7106  P09594   Velachery      1614            152        2.0         1.0
# 7107  P06508  Karapakkam       787             40        1.0         1.0
# 7108  P09794   Velachery      1896            156        3.0         2.0
#
#       N_ROOM    SALE_COND PARK_FACIL   BUILDTYPE UTILITY_AVAIL     STREET  \
# ...

# %%
data.shape
# Out:
# (7109, 19)

# %%
data.describe()
# Out:
#           INT_SQFT  DIST_MAINROAD    N_BEDROOM   N_BATHROOM       N_ROOM  \
# count  7109.000000    7109.000000  7108.000000  7104.000000  7109.000000
# mean   1382.073006      99.603179     1.637029     1.213260     3.688704
# std     457.410902      57.403110     0.802902     0.409639     1.019099
# min     500.000000       0.000000     1.000000     1.000000     2.000000
# 25%     993.000000      50.000000     1.000000     1.000000     3.000000
# 50%    1373.000000      99.000000     1.000000     1.000000     4.000000
# 75%    1744.000000     148.000000     2.000000     1.000000     4.000000
# max    2500.000000     200.000000     4.000000     2.000000     6.000000
#
#           QS_ROOMS  QS_BATHROOM   QS_BEDROOM   QS_OVERALL         COMMIS  \
# count  7109.000000  7109.000000  7109.000000  7061.000000    7109.000000
# mean      3.517471     3.507244     3.485300     3.503254  141005.726544
# std       0.891972     0.897834     0.887266     0.527223   78768.093718
# ...

# %%
data.dtypes
# Out:
# PRT_ID            object
# AREA              object
# INT_SQFT           int64
# DIST_MAINROAD      int64
# N_BEDROOM        float64
# N_BATHROOM       float64
# N_ROOM             int64
# SALE_COND         object
# PARK_FACIL        object
# BUILDTYPE         object
# UTILITY_AVAIL     object
# STREET            object
# MZZONE            object
# QS_ROOMS         float64
# QS_BATHROOM      float64
# QS_BEDROOM       float64
# QS_OVERALL       float64
# COMMIS             int64
# SALES_PRICE        int64
# dtype: object

# %%
data.plot.box()

# %%
data.describe(include="all")
# Out:
#         PRT_ID      AREA     INT_SQFT  DIST_MAINROAD    N_BEDROOM  \
# count     7109      7109  7109.000000    7109.000000  7108.000000
# unique    7109        17          NaN            NaN          NaN
# top     P08411  Chrompet          NaN            NaN          NaN
# freq         1      1681          NaN            NaN          NaN
# mean       NaN       NaN  1382.073006      99.603179     1.637029
# std        NaN       NaN   457.410902      57.403110     0.802902
# min        NaN       NaN   500.000000       0.000000     1.000000
# 25%        NaN       NaN   993.000000      50.000000     1.000000
# 50%        NaN       NaN  1373.000000      99.000000     1.000000
# 75%        NaN       NaN  1744.000000     148.000000     2.000000
# max        NaN       NaN  2500.000000     200.000000     4.000000
#
#          N_BATHROOM       N_ROOM SALE_COND PARK_FACIL BUILDTYPE UTILITY_AVAIL  \
# count   7104.000000  7109.000000      7109       7109      7109          7109
# ...

# %%
data["PARK_FACIL"].value_counts().plot.bar()

# %%
data["SALE_COND"].value_counts().plot.bar()

# %%
data["BUILDTYPE"].value_counts().plot.bar()

# %%
data['UTILITY_AVAIL'].value_counts().plot.bar()

# %%
data['MZZONE'].value_counts().plot.bar()

# %%
data.isnull().sum()
# Out:
# PRT_ID            0
# AREA              0
# INT_SQFT          0
# DIST_MAINROAD     0
# N_BEDROOM         1
# N_BATHROOM        5
# N_ROOM            0
# SALE_COND         0
# PARK_FACIL        0
# BUILDTYPE         0
# UTILITY_AVAIL     0
# STREET            0
# MZZONE            0
# QS_ROOMS          0
# QS_BATHROOM       0
# QS_BEDROOM        0
# QS_OVERALL       48
# COMMIS            0
# SALES_PRICE       0
# dtype: int64

# %%
data['SALES_PRICE'].plot.hist(bins= 50)

# %%
data['INT_SQFT'].plot.hist(bins= 50)

# %%
data['N_BATHROOM'].value_counts().plot.bar()

# %%
data['N_BEDROOM'].value_counts().plot.bar()

# %%
data['AREA'].value_counts().plot.bar()

# %% [markdown]
# ## Data Manipulation

# %%
data.drop_duplicates()
# Out:
#       PRT_ID        AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  \
# 0     P03210  Karapakkam      1004            131        1.0         1.0
# 1     P09411  Anna Nagar      1986             26        2.0         1.0
# 2     P01812       Adyar       909             70        1.0         1.0
# 3     P05346   Velachery      1855             14        3.0         2.0
# 4     P06210  Karapakkam      1226             84        1.0         1.0
# ...      ...         ...       ...            ...        ...         ...
# 7104  P03834  Karapakkam       598             51        1.0         1.0
# 7105  P10000   Velachery      1897             52        3.0         2.0
# 7106  P09594   Velachery      1614            152        2.0         1.0
# 7107  P06508  Karapakkam       787             40        1.0         1.0
# 7108  P09794   Velachery      1896            156        3.0         2.0
#
#       N_ROOM    SALE_COND PARK_FACIL   BUILDTYPE UTILITY_AVAIL     STREET  \
# ...

# %%
data.isnull().sum()
# Out:
# PRT_ID            0
# AREA              0
# INT_SQFT          0
# DIST_MAINROAD     0
# N_BEDROOM         1
# N_BATHROOM        5
# N_ROOM            0
# SALE_COND         0
# PARK_FACIL        0
# BUILDTYPE         0
# UTILITY_AVAIL     0
# STREET            0
# MZZONE            0
# QS_ROOMS          0
# QS_BATHROOM       0
# QS_BEDROOM        0
# QS_OVERALL       48
# COMMIS            0
# SALES_PRICE       0
# dtype: int64

# %% [markdown]
# # Fill the missing values for Bedrooms with MODE

# %%
data['N_BEDROOM'].mode()
# Out:
# 0    1.0
# dtype: float64

# %%
# replacinh null values in N_BEDROOM colomn to mode of the data set
data['N_BEDROOM'].fillna(value=data['N_BEDROOM'].mode(), inplace=True)

# %%
data.loc[data['N_BEDROOM'].isnull()]
# Out:
#       PRT_ID        AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  \
# 4060  P01066  Anna Nagar      1556            181        NaN         1.0
#
#       N_ROOM SALE_COND PARK_FACIL BUILDTYPE UTILITY_AVAIL     STREET MZZONE  \
# 4060       4  Partiall         No     House       NoSewr   No Access     RM
#
#       QS_ROOMS  QS_BATHROOM  QS_BEDROOM  QS_OVERALL  COMMIS  SALES_PRICE
# 4060       4.8          2.7         2.0       3.155  107978     10797790

# %% [markdown]
# # for each NULL bathroom fill it with number of bedrooms

# %%
data.loc[data['N_BATHROOM'].isnull()==True]
# Out:
#       PRT_ID        AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  \
# 70    P05304  Anna Nagar      1589             39        1.0         NaN
# 5087  P01333    Chrompet      1016            105        1.0         NaN
# 6134  P01332    Chormpet       916            173        1.0         NaN
# 6371  P01189    Chrompet      1035             90        1.0         NaN
# 6535  P09189  Anna Nagar      1864            184        2.0         NaN
#
#       N_ROOM    SALE_COND PARK_FACIL BUILDTYPE UTILITY_AVAIL     STREET  \
# 70         4      Partial         No    Others        AllPub     Gravel
# 5087       3     AbNormal        Yes    Others       NoSewr      Gravel
# 6134       3  Normal Sale        Yes    Others           ELO      Paved
# 6371       3      Partial         No    Others        NoSeWa  No Access
# 6535       5       Family        Yes    Others       NoSewr       Paved
#
#      MZZONE  QS_ROOMS  QS_BATHROOM  QS_BEDROOM  QS_OVERALL  COMMIS  \
# ...

# %%
# This for loop implementation will replace Missing Bathroom with
# 1 if Number of bedrooms = 1 else 2 . But since it is observed 
# that it gives same output for this data set we simply set bathroom to number of bedrooms

''' 
for i in range(0, len(data) ):
    if(pd.isnull(data['N_BATHROOM'][i])):
        if(data['N_BEDROOM'][i] == 1.0):
            data['N_BATHROOM'][i] = 1.0
        else:
            data['N_BATHROOM'][i] = 2.0
'''            
            
    
index = data['N_BATHROOM'].isnull()

data.loc[index,'N_BATHROOM'] = data.loc[index,'N_BEDROOM']
#data.loc[index,'N_BEDROOM']

# %%
data.loc[data['N_BATHROOM'].isnull()]
# Out:
# Empty DataFrame
# Columns: [PRT_ID, AREA, INT_SQFT, DIST_MAINROAD, N_BEDROOM, N_BATHROOM, N_ROOM, SALE_COND, PARK_FACIL, BUILDTYPE, UTILITY_AVAIL, STREET, MZZONE, QS_ROOMS, QS_BATHROOM, QS_BEDROOM, QS_OVERALL, COMMIS, SALES_PRICE]
# Index: []

# %% [markdown]
# # to impute missing values og QS_OVERALL we put mean of QS_ROOMS, QS_BATHROOM,QS_BEDROOM

# %%
# to impute missing values og QS_OVERALL we put mean of QS_ROOMS, QS_BATHROOM,QS_BEDROOM
data.loc[data['QS_OVERALL'].isnull()==True]
# Out:
#       PRT_ID        AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  \
# 15    P06328   Velachery      1868            148        3.0         2.0
# 46    P09483     T Nagar      1882            189        2.0         1.0
# 86    P00545    Chrompet      1085            149        1.0         1.0
# 111   P06768       Adyar      1034             73        1.0         1.0
# 134   P00089     T Nagar      1942             10        2.0         1.0
# 143   P06226  Karapakkam      1430             17        2.0         2.0
# 161   P06964   Velachery      1824            187        3.0         2.0
# 186   P08752       Adyar       738             69        1.0         1.0
# 208   P03292  Karapakkam      1578            153        2.0         2.0
# 248   P04891   Velachery      1776            120        2.0         1.0
# 261   P04590       Adyar      1249             93        2.0         2.0
# 284   P03587    KK Nagar      1632            156        2.0         1.0
# ...

# %%
'''
for i in range(0, len(data)):
    if(pd.isnull(data['QS_OVERALL'][i])==True):
        data['QS_OVERALL'][i] = (data['QS_ROOMS'][i] + data['QS_BATHROOM'][i] + data['QS_BEDROOM'][i])/3 '''


index = data['QS_OVERALL'].isnull()

data.loc[index, 'QS_OVERALL'] = (data.loc[index,'QS_ROOMS'] + 
                                 data.loc[index, 'QS_BATHROOM'] + 
                                 data.loc[index, 'QS_BEDROOM'])/3

# %% [markdown]
# # No more missing data

# %%
data.isnull().sum()
# Out:
# PRT_ID           0
# AREA             0
# INT_SQFT         0
# DIST_MAINROAD    0
# N_BEDROOM        1
# N_BATHROOM       5
# N_ROOM           0
# SALE_COND        0
# PARK_FACIL       0
# BUILDTYPE        0
# UTILITY_AVAIL    0
# STREET           0
# MZZONE           0
# QS_ROOMS         0
# QS_BATHROOM      0
# QS_BEDROOM       0
# QS_OVERALL       0
# COMMIS           0
# SALES_PRICE      0
# dtype: int64
